# %%
# 소상공인 상가업소 정보 서비스 
# https://www.data.go.kr/iim/api/selectAPIAcountView.do

# %%
api_key = '7a7151426e776c673937766e546363'

# %%
import urllib.request

# %%
#url00 = 'http://apis.data.go.kr/B553077/api/open/sdsc/storeListInDong?divId=ctprvnCd&key=11&ServiceKey=9g1c99d%2F5pmVFSfbjW8zZjeRhaTXN%2BkWjjLbPVEbjkBytn%2BHdJfuNYgJjva3Apz9XTF8yDhpa6sPKzlNUWNRnA%3D%3D'

# %%
#-*- coding:utf-8 -*-
url ='http://openAPI.seoul.go.kr:8088/'+api_key+'/json/ListCulturalFacilitiesBySubjectService/1/235/1/'

# %%
url
# Out:
# 'http://openAPI.seoul.go.kr:8088/7a7151426e776c673937766e546363/json/ListCulturalFacilitiesBySubjectService/1/235/1/'

# %%
response = urllib.request.urlopen(url)

# %%
response

# %%
json_str = response.read().decode("utf-8")

# %%
json_str
# Out:
# '{"ListCulturalFacilitiesBySubjectService":{"list_total_count":235,"RESULT":{"CODE":"INFO-000","MESSAGE":"정상 처리되었습니다"},"row":[{"FAC_CODE":"100517","SUBJCODE":1.0,"CODENAME":"공연장","FAC_NAME":"서울애니시네마","MAIN_IMG":"http://culture.seoul.go.kr/data/cf/20111101135312.jpg","ADDR":"서울  중구 예장동 8-145 )"},{"FAC_CODE":"100873","SUBJCODE":1.0,"CODENAME":"공연장","FAC_NAME":"명동난타극장","MAIN_IMG":"http://culture.seoul.go.kr/data/cf/20111101134510.jpg","ADDR":"서울  중구 명동길 26"},{"FAC_CODE":"100457","SUBJCODE":1.0,"CODENAME":"공연장","FAC_NAME":"연강홀","MAIN_IMG":"http://culture.seoul.go.kr/data/cf/title_100457.jpg","ADDR":"서울  종로구 연지동 270 )"},{"FAC_CODE":"100162","SUBJCODE":1.0,"CODENAME":"공연장","FAC_NAME":"그랜드 시네마","MAIN_IMG":"","ADDR":"서울  마포구 노고산동 57-1 )"},{"FAC_CODE":"100671","SUBJCODE":1.0,"CODENAME":"공연장","FAC_NAME":"우리금융아트홀","MAIN_IMG":"http://culture.seoul.go.kr/data/cf/title_100671.bmp","ADDR":"서울  송파구"},{"FAC_CODE":"100020","SUBJCODE":1.0,"CODENAME":"공연장","FAC_NAME":"코엑스 오디토리움","MAIN_IMG":"http://cultu
# ...

# %%
# json을 import 하여 문자열 -> json으로 변환

# %%
import json

# %%
json_object = json.loads(json_str)

# %%
json_object
# Out:
# {'ListCulturalFacilitiesBySubjectService': {'list_total_count': 235,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'FAC_CODE': '100517',
#     'SUBJCODE': 1.0,
#     'CODENAME': '공연장',
#     'FAC_NAME': '서울애니시네마',
#     'MAIN_IMG': 'http://culture.seoul.go.kr/data/cf/20111101135312.jpg',
#     'ADDR': '서울  중구 예장동 8-145 )'},
#    {'FAC_CODE': '100873',
#     'SUBJCODE': 1.0,
#     'CODENAME': '공연장',
#     'FAC_NAME': '명동난타극장',
#     'MAIN_IMG': 'http://culture.seoul.go.kr/data/cf/20111101134510.jpg',
#     'ADDR': '서울  중구 명동길 26'},
#    {'FAC_CODE': '100457',
#     'SUBJCODE': 1.0,
#     'CODENAME': '공연장',
#     'FAC_NAME': '연강홀',
#     'MAIN_IMG': 'http://culture.seoul.go.kr/data/cf/title_100457.jpg',
#     'ADDR': '서울  종로구 연지동 270 )'},
#    {'FAC_CODE': '100162',
#     'SUBJCODE': 1.0,
#     'CODENAME': '공연장',
#     'FAC_NAME': '그랜드 시네마',
#     'MAIN_IMG': '',
#     'ADDR': '서울  마포구 노고산동 57-1 )'},
#    {'FAC_CODE': '100671',
#     'SUBJCODE': 1.0,
# ...

# %%
# pandas를 이용해 json을 DataFrame 형태로
# 데이터를 보면 header와 body가 나뉜다. 우리가 필요한 정보는 body이니 그쪽 정보를 로드해서 pandas로 변형

# %%
import pandas as pd
from pandas.io.json import json_normalize

# %%
body = [json_object['ListCulturalFacilitiesBySubjectService']['row']]

# %%
body
# Out:
# [[{'FAC_CODE': '100517',
#    'SUBJCODE': 1.0,
#    'CODENAME': '공연장',
#    'FAC_NAME': '서울애니시네마',
#    'MAIN_IMG': 'http://culture.seoul.go.kr/data/cf/20111101135312.jpg',
#    'ADDR': '서울  중구 예장동 8-145 )'},
#   {'FAC_CODE': '100873',
#    'SUBJCODE': 1.0,
#    'CODENAME': '공연장',
#    'FAC_NAME': '명동난타극장',
#    'MAIN_IMG': 'http://culture.seoul.go.kr/data/cf/20111101134510.jpg',
#    'ADDR': '서울  중구 명동길 26'},
#   {'FAC_CODE': '100457',
#    'SUBJCODE': 1.0,
#    'CODENAME': '공연장',
#    'FAC_NAME': '연강홀',
#    'MAIN_IMG': 'http://culture.seoul.go.kr/data/cf/title_100457.jpg',
#    'ADDR': '서울  종로구 연지동 270 )'},
#   {'FAC_CODE': '100162',
#    'SUBJCODE': 1.0,
#    'CODENAME': '공연장',
#    'FAC_NAME': '그랜드 시네마',
#    'MAIN_IMG': '',
#    'ADDR': '서울  마포구 노고산동 57-1 )'},
#   {'FAC_CODE': '100671',
#    'SUBJCODE': 1.0,
#    'CODENAME': '공연장',
#    'FAC_NAME': '우리금융아트홀',
#    'MAIN_IMG': 'http://culture.seoul.go.kr/data/cf/title_100671.bmp',
#    'ADDR': '서울  송파구'},
# ...

# %%
type(body)
# Out:
# list

# %%
df = json_normalize(json_object['ListCulturalFacilitiesBySubjectService']['row']) #Results contain the required data
print(df)
# Out:
#    FAC_CODE  SUBJCODE CODENAME      FAC_NAME  \
# 0    100517       1.0      공연장       서울애니시네마
# 1    100873       1.0      공연장        명동난타극장
# 2    100457       1.0      공연장           연강홀
# 3    100162       1.0      공연장       그랜드 시네마
# 4    100671       1.0      공연장       우리금융아트홀
# 5    100020       1.0      공연장     코엑스 오디토리움
# 6    100197       1.0      공연장  예술의 전당 자유소극장
# 7    101230       1.0      공연장     서울 암사동 유적
# 8    100734       1.0      공연장        종로구민회관
# 9    100210       1.0      공연장         씨너스 G
# 10   100019       1.0      공연장         백암아트홀
# 11   100528       1.0      공연장      삼일로 창고극장
# 12   100416       1.0      공연장          판타지움
# 13   100413       1.0      공연장     대학로 열린 극장
# 14   100294       1.0      공연장  국립중앙박물관 극장 용
#
#                                              MAIN_IMG                   ADDR
# 0   http://culture.seoul.go.kr/data/cf/20111101135...     서울  중구 예장동 8-145 )
# 1   http://culture.seoul.go.kr/data/cf/20111101134...          서울  중구 명동길 26
# ...

# %%
df = pd.DataFrame(body)

# %%
df.to_csv('smb3.csv', encoding='utf-8-sig')

# %%
df.head()
# Out:
#                                                   0   \
# 0  {'FAC_CODE': '100517', 'SUBJCODE': 1.0, 'CODEN...
#
#                                                   1   \
# 0  {'FAC_CODE': '100873', 'SUBJCODE': 1.0, 'CODEN...
#
#                                                   2   \
# 0  {'FAC_CODE': '100457', 'SUBJCODE': 1.0, 'CODEN...
#
#                                                   3   \
# 0  {'FAC_CODE': '100162', 'SUBJCODE': 1.0, 'CODEN...
#
#                                                   4   \
# 0  {'FAC_CODE': '100671', 'SUBJCODE': 1.0, 'CODEN...
#
#                                                   5   \
# 0  {'FAC_CODE': '100020', 'SUBJCODE': 1.0, 'CODEN...
#
#                                                   6   \
# 0  {'FAC_CODE': '100197', 'SUBJCODE': 1.0, 'CODEN...
#
#                                                   7   \
# 0  {'FAC_CODE': '101230', 'SUBJCODE': 1.0, 'CODEN...
#
#                                                   8   \
# ...

# %%
url10 = 'http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsLclsCd&key=Q&ServiceKey='+api_key+'&type=json
# Out:
#   File "<ipython-input-20-934cd2c69696>", line 1
#     url10 = 'http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsLclsCd&key=Q&ServiceKey='+api_key+'&type=json
#                                                                                                                                    ^
# SyntaxError: EOL while scanning string literal

# %%
url10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-69bb97f4a0f0> in <module>
# ----> 1 url10
#
# NameError: name 'url10' is not defined

# %%
response = urllib.request.urlopen(url10)

# %%
json_str = response.read().decode("utf-8")

# %%
import json
json_object = json.loads(json_str)

# %%
jason_object

# %%
body = [jason_object['body']['items']]

# %%
df = pd.DataFrame(body)

# %%
df.head()
